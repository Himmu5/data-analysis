# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
customer_churn = pd.read_csv("../dataSET/Customer_Churn.csv")

# %%
customer_churn
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %% [markdown]
# __ Here are some analysis questions you can explore with this customer churn dataset:__
#
# ## Demographic Analysis
#
# ### What is the distribution of churn by gender?
#
# ### Does being a senior citizen affect churn rates?
#
# Service Usage & Churn
#
# ### How does having Internet service type (DSL, Fiber optic, None) affect churn?
#
# Is there a relationship between having tech support and churn rates?
#
# ## Contract & Payment Impact
#
# ### How do churn rates vary across different contract types (Month-to-month, One year, Two year)?
#
# ### Is churn higher for customers with paperless billing compared to those without?
#
# ## Tenure & Charges
#
# ### What is the average tenure of churned vs. non-churned customers?
#
# ### Do higher monthly charges correlate with higher churn?
#
# ## Combinations & Patterns
#
# ### Among customers without a partner or dependents, is churn rate higher?
#
# ### For customers with multiple streaming services, is churn higher or lower?

# %%
customer_churn.groupby("gender").value_counts()
# Out:
# gender  customerID  SeniorCitizen  Partner  Dependents  tenure  PhoneService  MultipleLines     InternetService  OnlineSecurity  OnlineBackup  DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract        PaperlessBilling  PaymentMethod              MonthlyCharges  TotalCharges  Churn
# Female  0002-ORFBO  0              Yes      Yes         9       Yes           No                DSL              No              Yes           No                Yes          Yes          No               One year        Yes               Mailed check               65.60           593.3         No       1
#         0013-EXCHZ  1              Yes      No          3       Yes           No                Fiber optic      No              No            No                Yes          Yes          No               Month-to-month  Yes               Mailed check               83.90           267.4         Yes      1
# ...

# %%
customer_churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
customer_with_phone = customer_churn.loc[customer_churn['PhoneService'] == "Yes"]

# %%
customer_with_phone
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 4     9237-HQITU  Female              0      No         No       2
# 5     9305-CDSKC  Female              0      No         No       8
# 6     1452-KIOVK    Male              0      No        Yes      22
# ...          ...     ...            ...     ...        ...     ...
# 7037  2569-WGERO  Female              0      No         No      72
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 1             Yes            No             DSL                  Yes  ...
# ...

# %%
customer_with_phone.groupby("gender").aggregate("gender").value_counts()
# Out:
# gender
# Female    3157
# Male      3204
# Name: count, dtype: int64

# %%
customer_with_phone.groupby("gender").aggregate("gender").value_counts().plot(kind='bar', figsize=(10, 6), title='Churn by gender with Phone Service')
# Out:
# <Axes: title={'center': 'Churn by gender with Phone Service'}, xlabel='gender'>

# %%
customer_churn['InternetService']
# Out:
# 0               DSL
# 1               DSL
# 2               DSL
# 3               DSL
# 4       Fiber optic
#            ...
# 7038            DSL
# 7039    Fiber optic
# 7040            DSL
# 7041    Fiber optic
# 7042    Fiber optic
# Name: InternetService, Length: 7043, dtype: object

# %%
customer_churn['InternetService'].value_counts()
# Out:
# InternetService
# Fiber optic    3096
# DSL            2421
# No             1526
# Name: count, dtype: int64

# %%
customer_churn.groupby("InternetService").aggregate("Churn").value_counts()
# Out:
# InternetService  Churn
# DSL              No       1962
#                  Yes       459
# Fiber optic      No       1799
#                  Yes      1297
# No               No       1413
#                  Yes       113
# Name: count, dtype: int64

# %%
customer_churn
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
customer_churn['Churn'].value_counts().plot(kind='bar', figsize=(10, 6), title='Churn Distribution')
# Out:
# <Axes: title={'center': 'Churn Distribution'}, xlabel='Churn'>
