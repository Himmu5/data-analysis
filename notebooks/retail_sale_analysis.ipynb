# %% [markdown]
# #### Retail Sale Data

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
# Database connection variables
username = "root"
password = ""
host = "localhost"   # or remote host IP
port = "3306"        # default MySQL port
database = "data_analysis"

# %%
conn = create_engine(f"mysql+pymysql://{username}:{password}@{host}:{port}/{database}")

# %%
pd.read_sql("select * from retail_sale LIMIT 10;", conn)
# Out:
#    transactions_id   sale_date       sale_time  customer_id  gender  age  \
# 0              180  2022-11-05 0 days 10:47:00          117    Male   41
# 1              522  2022-07-09 0 days 11:00:00           52    Male   46
# 2              559  2022-12-12 0 days 10:48:00            5  Female   40
# 3             1180  2022-01-06 0 days 08:53:00           85    Male   41
# 4             1522  2022-11-14 0 days 08:35:00           48    Male   46
# 5             1559  2022-08-20 0 days 07:40:00           49  Female   40
# 6              163  2022-10-31 0 days 09:38:00          144  Female   64
# 7              303  2022-04-22 0 days 11:09:00           54    Male   19
# 8              421  2022-04-08 0 days 08:43:00           66  Female   37
# 9              979  2022-05-18 0 days 10:18:00            6  Female   19
#
#       category  quantity  price_per_unit  cogs  total_sale
# 0     Clothing         3             300   129         900
# 1       Beauty         3             500   145        1500
# 2     Clothing         4             300    84        1200
# 3     Clothing         3             300   129         900
# 4       Beauty         3             500   235        1500
# 5     Clothing         4             300   144        1200
# 6     Clothing         3              50    23         150
# 7  Electronics         3              30    15          90
# 8     Clothing         3             500   235        1500
# 9       Beauty         1              25    11          25
