# %% [markdown]
# ### Google trends analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pytrends.request import TrendReq

# %%
pytrends = TrendReq(hl='en-US', tz=360)

# %%
interest_over_time = pytrends.interest_over_time()
# Out:
# /Users/himanshuchauhan/Desktop/data-science/.venv/lib/python3.13/site-packages/pytrends/request.py:260: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.fillna(False)

# %%
interest_over_time
# Out:
#             Blockchain  isPartial
# date
# 2020-08-16          41      False
# 2020-08-23          40      False
# 2020-08-30          37      False
# 2020-09-06          35      False
# 2020-09-13          36      False
# ...                ...        ...
# 2025-07-13          49      False
# 2025-07-20          56      False
# 2025-07-27          55      False
# 2025-08-03          60      False
# 2025-08-10          81       True
#
# [261 rows x 2 columns]

# %%
kw_list = ["Cloud Computing"]
pytrends.build_payload(kw_list, cat=0, timeframe='2024-01-01 2024-02-01', geo='', gprop='')
data = pytrends.interest_over_time()
data = data.sort_values(by="Cloud Computing", ascending = False)
data = data.head(10)
# Out:
#             Cloud Computing  isPartial
# date
# 2024-01-29              100      False
# 2024-01-03               98      False
# 2024-01-10               87      False
# 2024-01-30               86      False
# 2024-01-23               82      False
# 2024-01-24               80      False
# 2024-01-27               80      False
# 2024-01-08               80      False
# 2024-01-09               80      False
# 2024-01-31               78      False

# %%
data
# Out:
#             Cloud Computing  isPartial
# date
# 2024-01-29              100      False
# 2024-01-03               98      False
# 2024-01-10               87      False
# 2024-01-30               86      False
# 2024-01-23               82      False
# 2024-01-24               80      False
# 2024-01-27               80      False
# 2024-01-08               80      False
# 2024-01-09               80      False
# 2024-01-31               78      False

# %%
data = pytrends.interest_over_time()
data = data.sort_values(by="Cloud Computing", ascending = False)
data = data.head(10)
data.reset_index()
# Out:
#         date  Cloud Computing  isPartial
# 0 2024-01-29              100      False
# 1 2024-01-03               98      False
# 2 2024-01-10               87      False
# 3 2024-01-30               86      False
# 4 2024-01-23               82      False
# 5 2024-01-24               80      False
# 6 2024-01-27               80      False
# 7 2024-01-08               80      False
# 8 2024-01-09               80      False
# 9 2024-01-31               78      False

# %%
data = pytrends.interest_by_region()
data = data.sort_values(by="Cloud Computing", 
                        ascending = False)
data = data.head(10)

# %%
data
# Out:
#              Cloud Computing
# geoName
# St. Helena               100
# Ethiopia                  98
# Nepal                     90
# India                     69
# Cameroon                  57
# Sri Lanka                 47
# Ghana                     46
# Nigeria                   44
# Pakistan                  40
# South Korea               39

# %%
data.reset_index().plot(x='geoName', y='Cloud Computing',
                        figsize=(10,5), kind="bar")
plt.style.use('fivethirtyeight')
plt.show()
