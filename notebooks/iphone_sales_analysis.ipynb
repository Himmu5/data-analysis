# %% [markdown]
# # Iphone sales data EDA

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
from itertools import combinations

# %%
iphone_sales_data = pd.read_csv("../dataset/iphone_sales.csv")

# %% [markdown]
# #### How many unique customers made purchases?

# %%
len(iphone_sales_data['Email'].unique())
# Out:
# 525

# %% [markdown]
# #### Which customers purchased multiple products in a single transaction?

# %%
# iphone_sales_data.groupby("")
iphone_sales_data.loc[iphone_sales_data['Product'].str.split(",").str.len() > 1]
# Out:
#            Name                 Email  \
# 4      PERSON_5    PERSON_5@gmail.com
# 5      PERSON_6    PERSON_6@gmail.com
# 7      PERSON_8    PERSON_8@gmail.com
# 11    PERSON_12   PERSON_12@gmail.com
# 12    PERSON_13   PERSON_13@gmail.com
# ..          ...                   ...
# 575  PERSON_521  PERSON_521@gmail.com
# 576  PERSON_522  PERSON_522@gmail.com
# 578  PERSON_523  PERSON_523@gmail.com
# 579  PERSON_524  PERSON_524@gmail.com
# 580  PERSON_525  PERSON_525@gmail.com
#
#                                                Product     Transaction Date
# 4          PRODUCT_34,PRODUCT_86,PRODUCT_57,PRODUCT_89  01/03/2021 10:56:46
# 5          PRODUCT_34,PRODUCT_66,PRODUCT_58,PRODUCT_83  01/03/2021 11:06:34
# 7           PRODUCT_63,PRODUCT_90,PRODUCT_27,PRODUCT_5  01/03/2021 12:31:10
# 11                                PRODUCT_5,PRODUCT_34  01/03/2021 13:37:45
# 12                               PRODUCT_84,PRODUCT_27  01/03/2021 14:17:44
# ..                                                 ...                  ...
# 575  PRODUCT_92,PRODUCT_2,PRODUCT_41,PRODUCT_3,PROD...  07/03/2021 23:50:27
# 576  PRODUCT_48,PRODUCT_80,PRODUCT_71,PRODUCT_68,PR...  07/03/2021 23:53:03
# 578  PRODUCT_36,PRODUCT_14,PRODUCT_64,PRODUCT_28,PR...  07/03/2021 23:58:24
# 579  PRODUCT_75,PRODUCT_71,PRODUCT_86,PRODUCT_63,PR...  07/03/2021 23:59:26
# 580                              PRODUCT_66,PRODUCT_34  07/03/2021 23:59:19
#
# [235 rows x 4 columns]

# %% [markdown]
# #### Which customers have the highest number of transactions overall?

# %%
iphone_sales_data.aggregate("Email").value_counts().reset_index().head(1)
# Out:
#                   Email  count
# 0  PERSON_470@gmail.com      5

# %% [markdown]
# #### Can we identify repeat customers vs one-time buyers?

# %%
customer_with_frequency = iphone_sales_data.aggregate("Email").value_counts().reset_index()
# customer_with_frequency.loc[customer_with_frequency['count'] == 1]
customer_with_frequency.loc[customer_with_frequency['count'] > 1]
# Out:
#                           Email  count
# 0          PERSON_470@gmail.com      5
# 1          PERSON_330@gmail.com      4
# 2           PERSON_75@gmail.com      3
# 3          PERSON_156@gmail.com      3
# 4          PERSON_290@gmail.com      3
# 5        PERSON_283@hotmail.com      3
# 6          PERSON_263@gmail.com      2
# 7           PERSON_91@gmail.com      2
# 8          PERSON_207@gmail.com      2
# 9          PERSON_344@gmail.com      2
# 10         PERSON_343@gmail.com      2
# 11         PERSON_335@gmail.com      2
# 12          PERSON_71@gmail.com      2
# 13          PERSON_74@gmail.com      2
# 14         PERSON_195@gmail.com      2
# 15          PERSON_62@gmail.com      2
# 16    PERSON_477@rediffmail.com      2
# 17          PERSON_53@gmail.com      2
# 18    PERSON_52@moirasariya.com      2
# 19          PERSON_98@gmail.com      2
# 20         PERSON_435@gmail.com      2
# 21         PERSON_439@gmail.com      2
# 22         PERSON_247@gmail.com      2
# 23         PERSON_430@gmail.com      2
# 24         PERSON_181@gmail.com      2
# 25         PERSON_423@gmail.com      2
# 26         PERSON_180@gmail.com      2
# 27      PERSON_414@gcl-intl.com      2
# 28         PERSON_172@gmail.com      2
# 29         PERSON_131@gmail.com      2
# 30         PERSON_378@gmail.com      2
# 31         PERSON_133@gmail.com      2
# 32         PERSON_170@gmail.com      2
# 33         PERSON_166@gmail.com      2
# 34         PERSON_402@gmail.com      2
# 35         PERSON_145@gmail.com      2
# 36          PERSON_45@gmail.com      2
# 37         PERSON_394@gmail.com      2
# 38           PERSON_6@gmail.com      2
# 39         PERSON_523@gmail.com      2
# 40          PERSON_30@gmail.com      2
# 41         PERSON_35@ntpc.co.in      2
# 42           PERSON_8@gmail.com      2
# 43  PERSON_24@kamalmotors.co.in      2
# 44          PERSON_11@gmail.com      2
# 45          PERSON_26@yahoo.com      2
# 46       PERSON_298@hotmail.com      2

# %% [markdown]
# ## Product-Level Analysis
# #### What are the most frequently purchased products?

# %%
products = iphone_sales_data['Product'].str.split(',').explode()
most_frequent = products.value_counts().head(1)
most_frequent
# Out:
# Product
# PRODUCT_75    121
# Name: count, dtype: int64

# %% [markdown]
# #### How many products are typically bought per transaction (single vs multiple purchases)?

# %%
iphone_sales_data["Product Count"] = iphone_sales_data['Product'].str.split(",").apply(len)
distribution = iphone_sales_data["Product Count"].value_counts()
single_vs_multiple = iphone_sales_data["Product Count"].apply(lambda x: "Single" if x == 1 else "Multiple").value_counts()
single_vs_multiple
# Out:
# Product Count
# Single      346
# Multiple    235
# Name: count, dtype: int64

# %% [markdown]
# #### Which products are often purchased together (co-occurrence analysis)?

# %%
transactions = iphone_sales_data['Product'].str.split(',')

# %%
pair_counts = Counter()
for products in transactions:
    if len(products) > 1:
        # Create all unique pairs from a transaction
        pairs = combinations(sorted(products), 2)
        pair_counts.update(pairs)
co_occurrence_df = pd.DataFrame(pair_counts.items(), columns=["Product Pair", "Count"])
top_pairs = co_occurrence_df.sort_values(by="Count", ascending=False).head(10)
top_pairs
# Out:
#                  Product Pair  Count
# 13   (PRODUCT_27, PRODUCT_63)     28
# 52   (PRODUCT_68, PRODUCT_75)     20
# 222  (PRODUCT_12, PRODUCT_85)     17
# 20   (PRODUCT_63, PRODUCT_75)     16
# 161  (PRODUCT_12, PRODUCT_55)     15
# 227  (PRODUCT_28, PRODUCT_61)     14
# 219  (PRODUCT_12, PRODUCT_61)     14
# 257  (PRODUCT_62, PRODUCT_85)     14
# 220  (PRODUCT_12, PRODUCT_62)     14
# 249  (PRODUCT_55, PRODUCT_61)     14

# %%
iphone_sales_data
# Out:
#            Name                      Email  \
# 0      PERSON_1         PERSON_1@gmail.com
# 1      PERSON_2  PERSON_2@tataprojects.com
# 2      PERSON_3         PERSON_3@gmail.com
# 3      PERSON_4         PERSON_4@gmail.com
# 4      PERSON_5         PERSON_5@gmail.com
# ..          ...                        ...
# 576  PERSON_522       PERSON_522@gmail.com
# 577  PERSON_523       PERSON_523@gmail.com
# 578  PERSON_523       PERSON_523@gmail.com
# 579  PERSON_524       PERSON_524@gmail.com
# 580  PERSON_525       PERSON_525@gmail.com
#
#                                                Product    Transaction Date  \
# 0                                           PRODUCT_75 2021-03-01 00:47:26
# 1                                           PRODUCT_75 2021-03-01 02:04:07
# 2                                           PRODUCT_63 2021-03-01 09:10:43
# 3                                           PRODUCT_63 2021-03-01 09:49:48
# 4          PRODUCT_34,PRODUCT_86,PRODUCT_57,PRODUCT_89 2021-03-01 10:56:46
# ..                                                 ...                 ...
# 576  PRODUCT_48,PRODUCT_80,PRODUCT_71,PRODUCT_68,PR... 2021-03-07 23:53:03
# 577                                          PRODUCT_8 2021-03-07 23:55:01
# 578  PRODUCT_36,PRODUCT_14,PRODUCT_64,PRODUCT_28,PR... 2021-03-07 23:58:24
# 579  PRODUCT_75,PRODUCT_71,PRODUCT_86,PRODUCT_63,PR... 2021-03-07 23:59:26
# 580                              PRODUCT_66,PRODUCT_34 2021-03-07 23:59:19
#
#      Product Count
# 0                1
# 1                1
# 2                1
# 3                1
# 4                4
# ..             ...
# 576             25
# 577              1
# 578             21
# 579              5
# 580              2
#
# [581 rows x 5 columns]

# %%
iphone_sales_data["Transaction Date"] = pd.to_datetime(
    iphone_sales_data["Transaction Date"], format="%d/%m/%Y %H:%M:%S"
)

# %%
# Find earliest and latest transactions
earliest_txn = iphone_sales_data.loc[iphone_sales_data["Transaction Date"].idxmin()]
latest_txn   = iphone_sales_data.loc[iphone_sales_data["Transaction Date"].idxmax()]

# %%
earliest_txn[["Product", "Transaction Date"]]
# Out:
# Product                      PRODUCT_75
# Transaction Date    2021-03-01 00:47:26
# Name: 0, dtype: object

# %%
latest_txn[["Product", "Transaction Date"]]
# Out:
# Product             PRODUCT_75,PRODUCT_71,PRODUCT_86,PRODUCT_63,PR...
# Transaction Date                                  2021-03-07 23:59:26
# Name: 579, dtype: object

# %%
iphone_sales_data
# Out:
#            Name                      Email  \
# 0      PERSON_1         PERSON_1@gmail.com
# 1      PERSON_2  PERSON_2@tataprojects.com
# 2      PERSON_3         PERSON_3@gmail.com
# 3      PERSON_4         PERSON_4@gmail.com
# 4      PERSON_5         PERSON_5@gmail.com
# ..          ...                        ...
# 576  PERSON_522       PERSON_522@gmail.com
# 577  PERSON_523       PERSON_523@gmail.com
# 578  PERSON_523       PERSON_523@gmail.com
# 579  PERSON_524       PERSON_524@gmail.com
# 580  PERSON_525       PERSON_525@gmail.com
#
#                                                Product    Transaction Date  \
# 0                                           PRODUCT_75 2021-03-01 00:47:26
# 1                                           PRODUCT_75 2021-03-01 02:04:07
# 2                                           PRODUCT_63 2021-03-01 09:10:43
# 3                                           PRODUCT_63 2021-03-01 09:49:48
# 4          PRODUCT_34,PRODUCT_86,PRODUCT_57,PRODUCT_89 2021-03-01 10:56:46
# ..                                                 ...                 ...
# 576  PRODUCT_48,PRODUCT_80,PRODUCT_71,PRODUCT_68,PR... 2021-03-07 23:53:03
# 577                                          PRODUCT_8 2021-03-07 23:55:01
# 578  PRODUCT_36,PRODUCT_14,PRODUCT_64,PRODUCT_28,PR... 2021-03-07 23:58:24
# 579  PRODUCT_75,PRODUCT_71,PRODUCT_86,PRODUCT_63,PR... 2021-03-07 23:59:26
# 580                              PRODUCT_66,PRODUCT_34 2021-03-07 23:59:19
#
#      Product Count
# 0                1
# 1                1
# 2                1
# 3                1
# 4                4
# ..             ...
# 576             25
# 577              1
# 578             21
# 579              5
# 580              2
#
# [581 rows x 5 columns]

# %% [markdown]
# ## Time-Based Analysis

# %% [markdown]
# #### What is the distribution of sales over time (daily, weekly, monthly)?

# %%
iphone_sales_data["Transaction Date"] = pd.to_datetime(iphone_sales_data["Transaction Date"], format="%d/%m/%Y %H:%M:%S")

# %%
daily_sales = iphone_sales_data.groupby(iphone_sales_data['Transaction Date'].dt.date).size()
weekly_sales = iphone_sales_data.groupby(iphone_sales_data['Transaction Date'].dt.to_period("W")).size()
monthy_sales = iphone_sales_data.groupby(iphone_sales_data['Transaction Date'].dt.to_period("m")).size()

# %%
iphone_sales_data
# Out:
#            Name                      Email  \
# 0      PERSON_1         PERSON_1@gmail.com
# 1      PERSON_2  PERSON_2@tataprojects.com
# 2      PERSON_3         PERSON_3@gmail.com
# 3      PERSON_4         PERSON_4@gmail.com
# 4      PERSON_5         PERSON_5@gmail.com
# ..          ...                        ...
# 576  PERSON_522       PERSON_522@gmail.com
# 577  PERSON_523       PERSON_523@gmail.com
# 578  PERSON_523       PERSON_523@gmail.com
# 579  PERSON_524       PERSON_524@gmail.com
# 580  PERSON_525       PERSON_525@gmail.com
#
#                                                Product    Transaction Date  \
# 0                                           PRODUCT_75 2021-03-01 00:47:26
# 1                                           PRODUCT_75 2021-03-01 02:04:07
# 2                                           PRODUCT_63 2021-03-01 09:10:43
# 3                                           PRODUCT_63 2021-03-01 09:49:48
# 4          PRODUCT_34,PRODUCT_86,PRODUCT_57,PRODUCT_89 2021-03-01 10:56:46
# ..                                                 ...                 ...
# 576  PRODUCT_48,PRODUCT_80,PRODUCT_71,PRODUCT_68,PR... 2021-03-07 23:53:03
# 577                                          PRODUCT_8 2021-03-07 23:55:01
# 578  PRODUCT_36,PRODUCT_14,PRODUCT_64,PRODUCT_28,PR... 2021-03-07 23:58:24
# 579  PRODUCT_75,PRODUCT_71,PRODUCT_86,PRODUCT_63,PR... 2021-03-07 23:59:26
# 580                              PRODUCT_66,PRODUCT_34 2021-03-07 23:59:19
#
#      Product Count
# 0                1
# 1                1
# 2                1
# 3                1
# 4                4
# ..             ...
# 576             25
# 577              1
# 578             21
# 579              5
# 580              2
#
# [581 rows x 5 columns]

# %%
iphone_sales_data['Hour'] = iphone_sales_data['Transaction Date'].dt.hour
iphone_sales_data["DayOfWeek"] = iphone_sales_data["Transaction Date"].dt.day_name()

# %%
iphone_sales_data
# Out:
#            Name                      Email  \
# 0      PERSON_1         PERSON_1@gmail.com
# 1      PERSON_2  PERSON_2@tataprojects.com
# 2      PERSON_3         PERSON_3@gmail.com
# 3      PERSON_4         PERSON_4@gmail.com
# 4      PERSON_5         PERSON_5@gmail.com
# ..          ...                        ...
# 576  PERSON_522       PERSON_522@gmail.com
# 577  PERSON_523       PERSON_523@gmail.com
# 578  PERSON_523       PERSON_523@gmail.com
# 579  PERSON_524       PERSON_524@gmail.com
# 580  PERSON_525       PERSON_525@gmail.com
#
#                                                Product    Transaction Date  \
# 0                                           PRODUCT_75 2021-03-01 00:47:26
# 1                                           PRODUCT_75 2021-03-01 02:04:07
# 2                                           PRODUCT_63 2021-03-01 09:10:43
# 3                                           PRODUCT_63 2021-03-01 09:49:48
# 4          PRODUCT_34,PRODUCT_86,PRODUCT_57,PRODUCT_89 2021-03-01 10:56:46
# ..                                                 ...                 ...
# 576  PRODUCT_48,PRODUCT_80,PRODUCT_71,PRODUCT_68,PR... 2021-03-07 23:53:03
# 577                                          PRODUCT_8 2021-03-07 23:55:01
# 578  PRODUCT_36,PRODUCT_14,PRODUCT_64,PRODUCT_28,PR... 2021-03-07 23:58:24
# 579  PRODUCT_75,PRODUCT_71,PRODUCT_86,PRODUCT_63,PR... 2021-03-07 23:59:26
# 580                              PRODUCT_66,PRODUCT_34 2021-03-07 23:59:19
#
#      Product Count  hour DayOfWeek
# 0                1     0    Monday
# 1                1     2    Monday
# 2                1     9    Monday
# 3                1     9    Monday
# 4                4    10    Monday
# ..             ...   ...       ...
# 576             25    23    Sunday
# 577              1    23    Sunday
# 578             21    23    Sunday
# 579              5    23    Sunday
# 580              2    23    Sunday
#
# [581 rows x 7 columns]

# %%
hourly_sales = iphone_sales_data.groupby("Hour").size()
hourly_sales
# Out:
# Hour
# 0     17
# 1      4
# 2      3
# 3      1
# 5      3
# 6      2
# 7      6
# 8     10
# 9     14
# 10    24
# 11    37
# 12    51
# 13    33
# 14    28
# 15    41
# 16    29
# 17    27
# 18    33
# 19    42
# 20    39
# 21    41
# 22    45
# 23    51
# dtype: int64

# %%
daily_sales = iphone_sales_data.groupby("DayOfWeek").size()

# %%
daily_sales
# Out:
# DayOfWeek
# Friday        62
# Monday        38
# Saturday     100
# Sunday       144
# Thursday      85
# Tuesday       35
# Wednesday    117
# dtype: int64

# %% [markdown]
# #### Is there a trend in product sales over time?

# %% [markdown]
# #### What is the first and last transaction date in the dataset?

# %%
iphone_sales_data.head(1)
# Out:
#        Name               Email     Product    Transaction Date  \
# 0  PERSON_1  PERSON_1@gmail.com  PRODUCT_75 2021-03-01 00:47:26
#
#    Product Count  hour DayOfWeek  Hour
# 0              1     0    Monday     0

# %%
iphone_sales_data.tail(1)
# Out:
#            Name                 Email                Product  \
# 580  PERSON_525  PERSON_525@gmail.com  PRODUCT_66,PRODUCT_34
#
#        Transaction Date  Product Count  hour DayOfWeek  Hour
# 580 2021-03-07 23:59:19              2    23    Sunday    23

# %%
sorted_data = iphone_sales_data["Transaction Date"].sort_values()

# %%
sorted_data.head(1)
# Out:
# 0   2021-03-01 00:47:26
# Name: Transaction Date, dtype: datetime64[ns]

# %%
sorted_data.tail(1)
# Out:
# 579   2021-03-07 23:59:26
# Name: Transaction Date, dtype: datetime64[ns]

# %%
iphone_sales_data['domain'] = iphone_sales_data['Email'].str.split("@").str[1]

# %%
iphone_sales_data.aggregate('domain').value_counts().reset_index().head(1)
# Out:
#       domain  count
# 0  gmail.com    500

# %%
product_domain = iphone_sales_data[['Product', 'domain']].loc[iphone_sales_data['domain'] == "gmail.com"]

# %%
product_domain
# Out:
#                                                Product     domain
# 0                                           PRODUCT_75  gmail.com
# 2                                           PRODUCT_63  gmail.com
# 3                                           PRODUCT_63  gmail.com
# 4          PRODUCT_34,PRODUCT_86,PRODUCT_57,PRODUCT_89  gmail.com
# 5          PRODUCT_34,PRODUCT_66,PRODUCT_58,PRODUCT_83  gmail.com
# ..                                                 ...        ...
# 576  PRODUCT_48,PRODUCT_80,PRODUCT_71,PRODUCT_68,PR...  gmail.com
# 577                                          PRODUCT_8  gmail.com
# 578  PRODUCT_36,PRODUCT_14,PRODUCT_64,PRODUCT_28,PR...  gmail.com
# 579  PRODUCT_75,PRODUCT_71,PRODUCT_86,PRODUCT_63,PR...  gmail.com
# 580                              PRODUCT_66,PRODUCT_34  gmail.com
#
# [500 rows x 2 columns]

# %%
products = product_domain['Product'].str.split(",").explode()

# %%
products
# Out:
# 0      PRODUCT_75
# 2      PRODUCT_63
# 3      PRODUCT_63
# 4      PRODUCT_34
# 4      PRODUCT_86
#           ...
# 579    PRODUCT_86
# 579    PRODUCT_63
# 579    PRODUCT_54
# 580    PRODUCT_66
# 580    PRODUCT_34
# Name: Product, Length: 1148, dtype: object

# %%
products.value_counts().head(1)
# Out:
# Product
# PRODUCT_75    101
# Name: count, dtype: int64
